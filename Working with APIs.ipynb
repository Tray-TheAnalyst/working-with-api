# %%
#import the libraries
import requests
import pandas as pd
import time

# %%
#Keys and setting up the variables to make the API call
API_KEY = "AIzaSyCLQwfGsLtUh8qy72rbn2TjrzAcSTatAU4"
CHANNEL_ID = "UCZeaMkA5uOIDTGm7Gct199A"

# %%
#make API call and to grab data from that call
url = "https://www.googleapis.com/youtube/v3/search?key=" + API_KEY + "&channelId=" + CHANNEL_ID + "&part=snippet,id&order=date&maxResults=20"
response  = requests.get(url).json()

# %%
response['items'][0] #run through this list (aka array) and grab the info, then save it to variables -->for loop to run thru
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': 'v-zDtEqhhnadBORnSEiiQ4h839s',
#  'id': {'kind': 'youtube#video', 'videoId': '827doAab_fA'},
#  'snippet': {'publishedAt': '2023-05-11T14:26:50Z',
#   'channelId': 'UCZeaMkA5uOIDTGm7Gct199A',
#   'title': 'Beach night',
#   'description': 'Focus.',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/827doAab_fA/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/827doAab_fA/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/827doAab_fA/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Abundance Abundance',
#   'liveBroadcastContent': 'none',
#   'publishTime': '2023-05-11T14:26:50Z'}}

# %%
video_id = response['items'][0]['id']['videoId']
video_id
# Out:
# '827doAab_fA'

# %%
video_title = response['items'][0]['snippet']['title']
video_title
# Out:
# 'Beach night'

# %%
upload_date = response['items'][0]['snippet']['publishedAt']
upload_date
# Out:
# '2023-05-11T14:26:50Z'

# %%
#create Pandas dataframe..df
df = pd.DataFrame(columns=['video_id', 'video_title', 'upload_date'])
df
# Out:
# Empty DataFrame
# Columns: [video_id, video_title, upload_date]
# Index: []

# %%
#now create for loop to grab the pieces of the list (aka array) we just test above: video_id, video_title, and upload_date
data_to_append = [] # Create a list to store the data
for video in response['items']:
  if video['id']['kind'] == 'youtube#video':
    video_id = video['id']['videoId']
    video_title = video['snippet']['title']
    upload_date = video['snippet']['publishedAt']
    #print(video_id, video_title, upload_date)

    #save (or append) the data my for loop grabbed, to the df
    #df = data_to_append.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date}, ignore_index=True)
    data_to_append.append([video_id, video_title, upload_date])

# %%
df = pd.DataFrame(data_to_append, columns=['video_id', 'video_title', 'upload_date'])

# %%
df.head()
# Out:
#       video_id                        video_title           upload_date
# 0  827doAab_fA                        Beach night  2023-05-11T14:26:50Z
# 1  YNABbcTFlR0                    Skyline Game On  2023-05-11T14:23:11Z
# 2  Nk0iBg9GoQU  Relaxation in Venice on a gondola  2023-05-11T12:20:33Z
# 3  -iTUrHkMDnw        Relax above a forested lake  2023-05-10T14:34:26Z
# 4  fevjoBqLzv8                       Ocean sunset  2023-05-10T14:07:39Z
